# %%
import shutil
import random
from pathlib import Path
from typing import List, Dict, Optional

import pandas as pd


# ======================
#       CONFIG
# ======================

# Dossier racine de ta grande TUSZ (celle de ~70 Go, avec train/eval/test)
BIG_ROOT = Path(r"edf/")

# Dossier où sera créée la petite TUSZ ÉQUILIBRÉE (UNE SEULE dataset)
SMALL_ROOT = Path(r"edf_reduit")

# Splits à scanner dans la grosse base
SPLITS = ["train", "eval", "test"]   # adapte si tu n'as pas les trois

# Nombre TOTAL d'enregistrements souhaités dans la petite dataset
# Exemple: 200 => ~100 avec crise + ~100 sans crise au total
TARGET_TOTAL_RECORDINGS = 200

# Optionnel : ne garder qu'un type de montage (ex: "01_tcp_ar"), sinon None
ONLY_MONTAGE_DIR = "01_tcp_ar"      # ou None pour tous les montages

# Pour reproductibilité
RANDOM_SEED = 42
random.seed(RANDOM_SEED)


# ======================
#   FONCTIONS UTILES
# ======================

def has_seizure(csv_path: Path) -> bool:
    """
    Retourne True si le fichier csv_bi/csv contient au moins une étiquette 'seiz'.
    """
    try:
        df = pd.read_csv(csv_path, comment="#")
    except Exception as e:
        print("[WARN] Impossible de lire %s: %s" % (csv_path, e))
        return False

    if "label" not in df.columns:
        print("[WARN] colonne 'label' absente dans %s, considéré comme non-seizure." % csv_path)
        return False

    mask = df["label"].astype(str).str.contains("seiz", case=False)
    return bool(mask.any())


def find_annotation_file(edf_path: Path) -> Optional[Path]:
    """
    Trouve le fichier d'annotation correspondant à un EDF :
    priorité .csv_bi, sinon .csv. Retourne None si rien trouvé.
    """
    csv_bi = edf_path.with_suffix(".csv_bi")
    if csv_bi.exists():
        return csv_bi

    csv = edf_path.with_suffix(".csv")
    if csv.exists():
        return csv

    return None


def matches_montage_filter(edf_path: Path) -> bool:
    """
    Si ONLY_MONTAGE_DIR est défini (ex: "01_tcp_ar"),
    ne garde que les EDF dont le chemin contient ce dossier.
    Sinon, accepte tout.
    """
    if ONLY_MONTAGE_DIR is None:
        return True
    return ONLY_MONTAGE_DIR in edf_path.parts


def copy_recording_to_single_dataset(edf_path: Path,
                                     ann_path: Path,
                                     big_split_dir: Path,
                                     small_root: Path) -> None:
    """
    Copie l'EDF et son annotation dans small_root en supprimant le niveau 'train/eval/test'.
    Exemple :
      BIG_ROOT/train/aaaaaacz/s003_2010/01_tcp_ar/xxx.edf
    devient :
      SMALL_ROOT/aaaaaacz/s003_2010/01_tcp_ar/xxx.edf
    """
    # Chemin relatif à partir du dossier de split (train / eval / test)
    rel_edf = edf_path.relative_to(big_split_dir)
    dest_edf = small_root / rel_edf
    dest_edf.parent.mkdir(parents=True, exist_ok=True)
    shutil.copy2(edf_path, dest_edf)

    rel_ann = ann_path.relative_to(big_split_dir)
    dest_ann = small_root / rel_ann
    dest_ann.parent.mkdir(parents=True, exist_ok=True)
    shutil.copy2(ann_path, dest_ann)


# ======================
#          MAIN
# ======================

def main():
    if not BIG_ROOT.exists():
        raise FileNotFoundError("BIG_ROOT introuvable : %s" % BIG_ROOT)

    SMALL_ROOT.mkdir(parents=True, exist_ok=True)

    # On agrège TOUTES les infos (train + eval + test)
    seiz_recs = []      # liste de dicts {"edf": Path, "ann": Path, "split": str}
    nonseiz_recs = []

    # 1) Scanner tous les splits
    for split in SPLITS:
        split_dir = BIG_ROOT / split
        if not split_dir.exists():
            print("[INFO] Split %s introuvable, on saute." % split)
            continue

        print("\n===== SCAN SPLIT : %s =====" % split)
        edf_files = sorted(split_dir.rglob("*.edf"))
        print("  %d fichiers EDF trouvés dans %s." % (len(edf_files), split))

        for edf_path in edf_files:
            if not matches_montage_filter(edf_path):
                continue

            ann_path = find_annotation_file(edf_path)
            if ann_path is None:
                print("[WARN] Pas de csv_bi/csv pour %s, on ignore." % edf_path)
                continue

            rec_info = {"edf": edf_path, "ann": ann_path, "split": split}

            if has_seizure(ann_path):
                seiz_recs.append(rec_info)
            else:
                nonseiz_recs.append(rec_info)

    # 2) Résumé global
    print("\n===== RÉSUMÉ GLOBAL =====")
    print("  Total enregistrements avec crise   :", len(seiz_recs))
    print("  Total enregistrements sans crise   :", len(nonseiz_recs))

    if len(seiz_recs) == 0 or len(nonseiz_recs) == 0:
        print("[ERREUR] Impossible d'équilibrer : une des classes est vide.")
        return

    if TARGET_TOTAL_RECORDINGS is None:
        max_per_class_from_target = min(len(seiz_recs), len(nonseiz_recs))
    else:
        max_per_class_from_target = TARGET_TOTAL_RECORDINGS // 2

    per_class = min(len(seiz_recs), len(nonseiz_recs), max_per_class_from_target)

    if per_class == 0:
        print("[ERREUR] per_class = 0 (TARGET_TOTAL_RECORDINGS trop petit ou trop peu de données).")
        return

    print("  => On va construire une petite dataset UNIQUE avec :")
    print("       %d enregistrements avec crise" % per_class)
    print("       %d enregistrements sans crise" % per_class)
    print("     soit un total ≈ %d enregistrements." % (2 * per_class))

    # 3) Échantillonnage équilibré
    seiz_selected = random.sample(seiz_recs, per_class)
    nonseiz_selected = random.sample(nonseiz_recs, per_class)

    # 4) Copie dans la petite dataset (sans niveau train/eval/test)
    print("\n===== COPIE VERS DATASET UNIQUE =====")
    for rec in seiz_selected + nonseiz_selected:
        edf_path = rec["edf"]
        ann_path = rec["ann"]
        split = rec["split"]
        split_dir = BIG_ROOT / split
        copy_recording_to_single_dataset(edf_path, ann_path, split_dir, SMALL_ROOT)

    print("\n=== Terminé ===")
    print("Petite dataset équilibrée (seizure / non-seizure) créée dans :")
    print("  %s" % SMALL_ROOT)


if __name__ == "__main__":
    main()

# %%
from dataclasses import dataclass
from pathlib import Path
from typing import List, Tuple, Optional, Dict, Any

import numpy as np
import pandas as pd
import mne
from scipy.signal import stft


# ======================
#      CONFIG GLOBALE
# ======================

@dataclass
class Config:
    # Chemins
    raw_root: Path          # dossier racine de la NOUVELLE dataset réduite (sans train/eval/test)
    prepared_root: Path     # dossier de sortie (contenant prepared/)
    split: str = "train"    # juste un nom logique pour le sous-dossier de sortie

    # EEG
    montage: Optional[str] = None   # on n'essaie plus d'appliquer "TCP_AR" de MNE
    l_freq: float = 0.5
    h_freq: float = 40.0
    notch_freq: Optional[float] = 50.0
    sfreq_target: Optional[float] = 256.0  # resampling

    # Fenêtres temporelles
    win_size: float = 4.0    # secondes
    hop_size: float = 2.0    # secondes (overlap 50% si hop = win/2)

    # Intervalles pré-/inter-ictaux
    preictal_dur: float = 120.0
    inter_tampon: float = 60.0   # tampon APRÈS la dernière crise pour l'interictal
    min_preictal: float = 60.0   # si onset < 60s → pas de pré-ictal exploitable

    # Spectrogrammes
    nperseg: int = 256
    noverlap: int = 128
    fmin_spec: float = 0.5
    fmax_spec: float = 40.0

    # Séquences optionnelles
    make_sequences: bool = True
    seq_len: int = 10

    # Filtrage patients / sessions (optionnel)
    patients_whitelist: Optional[List[str]] = None   # ex: ["aaaaaacz", "aaaaaaju"]
    sessions_whitelist: Optional[List[str]] = None   # ex: ["s003_2010", "s005_2010"]


Interval = Tuple[float, float]

# ======================
#   MONTAGE À GARDER
# ======================

ONLY_MONTAGE_DIR = "01_tcp_ar"


def get_patient_session_from_path(edf_path: Path) -> Tuple[str, str]:
    """
    Extrait patient et session à partir du chemin TUSZ.
    Pour la dataset réduite :
      .../data_small_one/aaaaaacz/s003_2010/01_tcp_ar/aaaaaacz_s003_t000.edf
      -> patient = aaaaaacz, session = s003_2010
    """
    parts = edf_path.parts
    if len(parts) < 4:
        return ("unknown", "unknown")
    patient = parts[-4]
    session = parts[-3]
    return patient, session


def is_01_tcp_ar_recording(edf_path: Path, cfg: Config) -> bool:
    """
    True si le fichier EDF :
      - appartient à un dossier de montage 01_tcp_ar
      - et respecte éventuellement les whitelists patient/session.
    """
    parts = edf_path.parts
    if ONLY_MONTAGE_DIR not in parts:
        return False

    # Récupérer patient et session
    patient, session = get_patient_session_from_path(edf_path)

    # Filtre patient
    if cfg.patients_whitelist is not None:
        if patient not in cfg.patients_whitelist:
            return False

    # Filtre session
    if cfg.sessions_whitelist is not None:
        if session not in cfg.sessions_whitelist:
            return False

    return True


# ======================
#   OUTILS SUR LES INTERVALLES
# ======================

def merge_intervals(intervals: List[Interval]) -> List[Interval]:
    """Fusionne des intervalles qui se chevauchent."""
    if not intervals:
        return []
    intervals = sorted(intervals, key=lambda x: x[0])
    merged = [list(intervals[0])]
    for s, e in intervals[1:]:
        last_s, last_e = merged[-1]
        if s <= last_e:
            merged[-1][1] = max(last_e, e)
        else:
            merged.append([s, e])
    return [(s, e) for s, e in merged]


def is_inside_intervals(start: float, end: float, intervals: List[Interval]) -> bool:
    """Vrai si [start, end] est entièrement inclus dans au moins un intervalle."""
    for s, e in intervals:
        if start >= s and end <= e:
            return True
    return False


# ======================
#       LECTURE CSV_BI
# ======================

def read_seizure_intervals(csv_bi_path: Path) -> List[Interval]:
    """
    Lit le fichier csv_bi global et renvoie la liste des intervalles de crise (seiz).
    """
    df = pd.read_csv(csv_bi_path, comment="#")
    if "label" not in df.columns or "start_time" not in df.columns or "stop_time" not in df.columns:
        raise ValueError(f"Colonnes manquantes dans {csv_bi_path}")
    mask = df["label"].astype(str).str.contains("seiz", case=False)
    seizures = df[mask]
    return [(float(row.start_time), float(row.stop_time)) for row in seizures.itertuples(index=False)]


def compute_intervals(duration: float,
                      seizures: List[Interval],
                      cfg: Config) -> Dict[str, List[Interval]]:
    """
    À partir de la durée d'un enregistrement et des intervalles de crises,
    calcule les intervalles :
      - 'preictal': intervalle pré-ictal juste AVANT la 1ère crise
      - 'interictal': intervalle inter-ictal APRÈS la DERNIÈRE crise + tampon
    Tout le reste est ignoré (fenêtres exclues).
    """
    if not seizures:
        # Pas de crise : tout est inter-ictal
        return {
            "preictal": [],
            "interictal": [(0.0, duration)],
        }

    seizures = sorted(seizures, key=lambda x: x[0])
    first_onset, first_offset = seizures[0]
    last_onset, last_offset = seizures[-1]

    preictal: List[Interval] = []
    interictal: List[Interval] = []

    # ----- Préictal : juste avant la 1ère crise -----
    if first_onset >= cfg.min_preictal:
        pre_start = max(0.0, first_onset - cfg.preictal_dur)
        pre_end = first_onset
        preictal.append((pre_start, pre_end))
        preictal = merge_intervals(preictal)
    else:
        preictal = []

    # ----- Interictal : APRÈS la dernière crise + tampon -----
    post_start = min(duration, last_offset + cfg.inter_tampon)
    if post_start < duration:
        interictal.append((post_start, duration))
        interictal = merge_intervals(interictal)
    else:
        interictal = []

    return {
        "preictal": preictal,
        "interictal": interictal,
    }


# ======================
#   SPECTROGRAMMES
# ======================

def make_spectrogram(window_data: np.ndarray, sfreq: float, cfg: Config) -> np.ndarray:
    """
    Transforme [C, samples] en spectrogramme [C, F, T].
    """
    window_data = window_data.astype(np.float32)

    f, t, Zxx = stft(window_data,
                     fs=sfreq,
                     nperseg=cfg.nperseg,
                     noverlap=cfg.noverlap,
                     axis=-1,
                     boundary=None)
    # Garder la bande de fréquences désirée
    band = (f >= cfg.fmin_spec) & (f <= cfg.fmax_spec)
    Zxx = Zxx[:, band, :]
    # Puissance
    Sxx = np.abs(Zxx) ** 2
    # Log
    Sxx = np.log10(Sxx + 1e-10)
    # Normalisation par canal
    C, F, T = Sxx.shape
    Sxx_norm = np.empty_like(Sxx, dtype=np.float32)
    for c in range(C):
        chan = Sxx[c]
        mean = chan.mean()
        std = chan.std()
        if std < 1e-6:
            Sxx_norm[c] = (chan - mean).astype(np.float32)
        else:
            Sxx_norm[c] = ((chan - mean) / std).astype(np.float32)
    return Sxx_norm


# ======================
#   TRAITEMENT D'UN EDF
# ======================

def process_one_recording(edf_path: Path, csv_bi_path: Path, cfg: Config,
                          windows_dir: Path,
                          sequences_dir: Optional[Path],
                          windows_rows: List[Dict[str, Any]],
                          sequences_rows: List[Dict[str, Any]]):
    """
    Traite un seul fichier EDF :
     - lit le signal
     - calcule les intervalles pré-/inter-ictaux
     - découpe en fenêtres
     - transforme en spectrogrammes
     - sauvegarde les .npy + met à jour les CSV index (windows & séquences).
    """
    print(f"==> Traitement de {edf_path}")

    patient, session = get_patient_session_from_path(edf_path)
    rec_name = edf_path.stem  # ex: xxx_s003_t000

    # --- 1) Crises depuis csv_bi ---
    try:
        seizures = read_seizure_intervals(csv_bi_path)
    except Exception as e:
        print(f"   [ERREUR] lecture csv_bi {csv_bi_path}: {e}")
        return

    # --- 2) Lire le signal EDF ---
    try:
        raw = mne.io.read_raw_edf(edf_path, preload=True, verbose=False)
    except Exception as e:
        print(f"   [ERREUR] lecture EDF {edf_path}: {e}")
        return

    # Garder seulement EEG
    raw.pick_types(eeg=True)

    # Montage MNE désactivé (TCP_AR n'existe pas en standard)
    if cfg.montage is not None:
        try:
            montage = mne.channels.make_standard_montage(cfg.montage)
            raw.set_montage(montage, on_missing='ignore')
        except Exception as e:
            print(f"   [WARN] montage non appliqué ({e})")

    # Filtre bande
    raw.filter(cfg.l_freq, cfg.h_freq, fir_design="firwin", verbose=False)

    # Notch 50/60 Hz si demandé
    if cfg.notch_freq is not None:
        freqs = np.array([cfg.notch_freq, cfg.notch_freq * 2])
        raw.notch_filter(freqs=freqs, verbose=False)

    # Resample
    if cfg.sfreq_target is not None:
        raw.resample(cfg.sfreq_target, verbose=False)
    sfreq = raw.info["sfreq"]
    duration = raw.n_times / sfreq

    # --- 3) Intervalles pré-/inter-ictaux ---
    intervals = compute_intervals(duration, seizures, cfg)
    preictal_intervals = intervals["preictal"]
    interictal_intervals = intervals["interictal"]

    # --- 4) Fenêtrage ---
    win_samp = int(round(cfg.win_size * sfreq))
    hop_samp = int(round(cfg.hop_size * sfreq))

    local_windows_specs: List[np.ndarray] = []
    local_windows_meta: List[Dict[str, Any]] = []

    win_idx = 0
    start_samp = 0
    while start_samp + win_samp <= raw.n_times:
        end_samp = start_samp + win_samp
        t_start = start_samp / sfreq
        t_end = end_samp / sfreq

        # Label en fonction des intervalles
        if is_inside_intervals(t_start, t_end, preictal_intervals):
            label = 1
        elif is_inside_intervals(t_start, t_end, interictal_intervals):
            label = 0
        else:
            start_samp += hop_samp
            continue

        # Extraire les données EEG : [C, samples]
        data = raw.get_data(start=start_samp, stop=end_samp)
        data = (data * 1e6).astype(np.float32)

        # Spectrogramme [C, F, T]
        spec = make_spectrogram(data, sfreq, cfg)

        # Sauvegarde .npy pour cette fenêtre
        out_name = f"{rec_name}_win{win_idx:04d}.npy"
        out_path = windows_dir / out_name
        np.save(out_path, spec)

        rel_path = out_path.relative_to(cfg.prepared_root)

        meta = {
            "path": str(rel_path).replace("\\", "/"),
            "label": int(label),
            "patient": patient,
            "session": session,
            "recording": rec_name,
            "t_start": t_start,
            "t_end": t_end,
        }
        windows_rows.append(meta)
        local_windows_specs.append(spec)
        local_windows_meta.append(meta)

        win_idx += 1
        start_samp += hop_samp

    print(
        f"   -> {len(local_windows_meta)} fenêtres gardées "
        f"(preictal={sum(m['label']==1 for m in local_windows_meta)}, "
        f"interictal={sum(m['label']==0 for m in local_windows_meta)})"
    )

    # --- 5) Optionnel : séquences de N fenêtres ---
    if cfg.make_sequences and sequences_dir is not None and len(local_windows_specs) >= cfg.seq_len:
        num_seq = 0
        for i in range(len(local_windows_specs) - cfg.seq_len + 1):
            seq_specs = local_windows_specs[i:i + cfg.seq_len]
            seq_meta = local_windows_meta[i:i + cfg.seq_len]

            X_seq = np.stack(seq_specs, axis=0).astype(np.float32)  # [N, C, F, T]
            label_seq = seq_meta[-1]["label"]
            last_center_s = 0.5 * (seq_meta[-1]["t_start"] + seq_meta[-1]["t_end"])

            seq_name = f"{rec_name}_seq{num_seq:04d}.npy"
            seq_path = sequences_dir / seq_name

            try:
                np.save(seq_path, X_seq)
            except OSError as e:
                print(f"   [ERREUR] impossible de sauvegarder la séquence {seq_name}: {e}")
                continue

            rel_seq_path = seq_path.relative_to(cfg.prepared_root)

            sequences_rows.append({
                "path": str(rel_seq_path).replace("\\", "/"),
                "label": int(label_seq),
                "patient": patient,
                "session": session,
                "recording": rec_name,
                "last_win_center_s": last_center_s,
            })
            num_seq += 1

        print(f"   -> {num_seq} séquences de {cfg.seq_len} fenêtres créées.")


# ======================
#   FONCTION D'ÉQUILIBRAGE
# ======================

def make_balanced_index(windows_rows: List[Dict[str, Any]],
                        sequences_rows: List[Dict[str, Any]],
                        prepared_split_dir: Path):
    """
    Crée des index équilibrés preictal/interictal pour les fenêtres et, si possible, pour les séquences.
    On sous-échantillonne l'interictal pour avoir ~autant de 0 que de 1.
    """
    if not windows_rows:
        print("\n[INFO] Aucun fenêtre, index équilibré non créé.")
        return

    df_win = pd.DataFrame(windows_rows)
    n_pre = (df_win["label"] == 1).sum()
    n_inter = (df_win["label"] == 0).sum()
    print(f"\n[STATS] Fenêtres totales: {len(df_win)} (preictal={n_pre}, interictal={n_inter})")

    if n_pre == 0 or n_inter == 0:
        print("[WARN] Impossible d'équilibrer (une des classes est vide).")
        balanced_win = df_win
    else:
        n_target = min(n_pre, n_inter)
        pre_df = df_win[df_win["label"] == 1]
        inter_df = df_win[df_win["label"] == 0]

        pre_sample = pre_df.sample(n=n_target, random_state=42) if n_pre > n_target else pre_df
        inter_sample = inter_df.sample(n=n_target, random_state=42) if n_inter > n_target else inter_df

        balanced_win = pd.concat([pre_sample, inter_sample], axis=0).sample(frac=1.0, random_state=42)
        print(f"[OK] Index fenêtres équilibré: {len(balanced_win)} lignes (≈ {n_target} + {n_target}).")

    balanced_win_path = prepared_split_dir / "train_windows_index_balanced.csv"
    balanced_win.to_csv(balanced_win_path, index=False)
    print(f"Index fenêtres équilibré sauvegardé dans {balanced_win_path}")

    # Même logique possible pour les séquences (si elles existent)
    if sequences_rows:
        df_seq = pd.DataFrame(sequences_rows)
        n_pre_s = (df_seq["label"] == 1).sum()
        n_inter_s = (df_seq["label"] == 0).sum()
        print(f"\n[STATS] Séquences totales: {len(df_seq)} (preictal={n_pre_s}, interictal={n_inter_s})")

        if n_pre_s == 0 or n_inter_s == 0:
            print("[WARN] Impossible d'équilibrer les séquences (une des classes est vide).")
            balanced_seq = df_seq
        else:
            n_target_s = min(n_pre_s, n_inter_s)
            pre_seq = df_seq[df_seq["label"] == 1]
            inter_seq = df_seq[df_seq["label"] == 0]

            pre_seq_sample = pre_seq.sample(n=n_target_s, random_state=42) if n_pre_s > n_target_s else pre_seq
            inter_seq_sample = inter_seq.sample(n=n_target_s, random_state=42) if n_inter_s > n_target_s else inter_seq

            balanced_seq = pd.concat([pre_seq_sample, inter_seq_sample], axis=0).sample(frac=1.0, random_state=42)
            print(f"[OK] Index séquences équilibré: {len(balanced_seq)} lignes (≈ {n_target_s} + {n_target_s}).")

        balanced_seq_path = prepared_split_dir / "train_sequences_index_balanced.csv"
        balanced_seq.to_csv(balanced_seq_path, index=False)
        print(f"Index séquences équilibré sauvegardé dans {balanced_seq_path}")


# ======================
#        MAIN
# ======================

def main():
    # ⚠️ ADAPTER CES CHEMINS À TA NOUVELLE DATASET RÉDUITE
    cfg = Config(
        raw_root=Path(r"edf_reduit/"),  # <-- racine de la dataset réduite
        prepared_root=Path(r"prepared/"),
        split="all",               # juste un nom (tu peux mettre "all" au lieu de "train")
        make_sequences=True,
        seq_len=10,
        patients_whitelist=None,
        sessions_whitelist=None,
    )

    # 🔹 ICI : contrairement à avant, on NE met plus /cfg.split pour lire les EDF
    raw_dir = cfg.raw_root                       # la petite dataset unique
    split_out_dir = cfg.prepared_root / cfg.split
    windows_dir = split_out_dir / "windows"
    sequences_dir = split_out_dir / "sequences" if cfg.make_sequences else None

    windows_dir.mkdir(parents=True, exist_ok=True)
    if sequences_dir is not None:
        sequences_dir.mkdir(parents=True, exist_ok=True)

    windows_rows: List[Dict[str, Any]] = []
    sequences_rows: List[Dict[str, Any]] = []

    # Parcourir tous les .edf de la dataset réduite
    edf_files = sorted(raw_dir.rglob("*.edf"))

    for edf_path in edf_files:
        # Filtrer : ne garder que les enregistrements 01_tcp_ar + whitelist
        if not is_01_tcp_ar_recording(edf_path, cfg):
            continue

        # Fichier d'annotations globales : même base que l'EDF
        csv_bi_path = edf_path.with_suffix(".csv_bi")
        if not csv_bi_path.exists():
            csv_bi_path = edf_path.with_suffix(".csv")
        if not csv_bi_path.exists():
            print(f"[WARN] csv_bi introuvable pour {edf_path}")
            continue

        process_one_recording(
            edf_path=edf_path,
            csv_bi_path=csv_bi_path,
            cfg=cfg,
            windows_dir=windows_dir,
            sequences_dir=sequences_dir,
            windows_rows=windows_rows,
            sequences_rows=sequences_rows,
        )

    # Index brut (non équilibré)
    windows_index_path = split_out_dir / "windows_index_all.csv"
    pd.DataFrame(windows_rows).to_csv(windows_index_path, index=False)
    print(f"\nIndex fenêtres (brut) sauvegardé dans {windows_index_path} ({len(windows_rows)} lignes)")

    if cfg.make_sequences and sequences_rows:
        seq_index_path = split_out_dir / "sequences_index_all.csv"
        pd.DataFrame(sequences_rows).to_csv(seq_index_path, index=False)
        print(f"Index séquences (brut) sauvegardé dans {seq_index_path} ({len(sequences_rows)} lignes)")

    # Création des index équilibrés
    make_balanced_index(windows_rows, sequences_rows, split_out_dir)


if __name__ == "__main__":
    main()
# Out:
# ==> Traitement de edf_reduit\aaaaaarq\s017_2014\01_tcp_ar\aaaaaarq_s017_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 491 fenêtres gardées (preictal=58, interictal=433)
#    -> 482 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaarq\s018_2014\01_tcp_ar\aaaaaarq_s018_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaasy\s003_2003\01_tcp_ar\aaaaaasy_s003_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 33 fenêtres gardées (preictal=0, interictal=33)
#    -> 24 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaasy\s003_2003\01_tcp_ar\aaaaaasy_s003_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 66 fenêtres gardées (preictal=0, interictal=66)
#    -> 57 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaasy\s003_2003\01_tcp_ar\aaaaaasy_s003_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaasy\s003_2003\01_tcp_ar\aaaaaasy_s003_t011.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaasy\s003_2003\01_tcp_ar\aaaaaasy_s003_t013.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaachj\s002_2004\01_tcp_ar\aaaaachj_s002_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 13 fenêtres gardées (preictal=0, interictal=13)
#    -> 4 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaedy\s001_2004\01_tcp_ar\aaaaaedy_s001_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaegi\s003_2013\01_tcp_ar\aaaaaegi_s003_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 87 fenêtres gardées (preictal=40, interictal=47)
#    -> 78 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaafzt\s003_2013\01_tcp_ar\aaaaafzt_s003_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 194 fenêtres gardées (preictal=58, interictal=136)
#    -> 185 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaghb\s010_2014\01_tcp_ar\aaaaaghb_s010_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 14 fenêtres gardées (preictal=0, interictal=14)
#    -> 5 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaghb\s010_2014\01_tcp_ar\aaaaaghb_s010_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 56 fenêtres gardées (preictal=42, interictal=14)
#    -> 47 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaagpk\s012_2014\01_tcp_ar\aaaaagpk_s012_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaagxr\s022_2015\01_tcp_ar\aaaaagxr_s022_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaahlk\s006_2014\01_tcp_ar\aaaaahlk_s006_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 308 fenêtres gardées (preictal=58, interictal=250)
#    -> 299 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaahlk\s006_2014\01_tcp_ar\aaaaahlk_s006_t009.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 177 fenêtres gardées (preictal=58, interictal=119)
#    -> 168 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaahlk\s007_2014\01_tcp_ar\aaaaahlk_s007_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 259 fenêtres gardées (preictal=58, interictal=201)
#    -> 250 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaahsi\s013_2014\01_tcp_ar\aaaaahsi_s013_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 31 fenêtres gardées (preictal=0, interictal=31)
#    -> 22 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaahsi\s014_2014\01_tcp_ar\aaaaahsi_s014_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 77 fenêtres gardées (preictal=47, interictal=30)
#    -> 68 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaiat\s006_2012\01_tcp_ar\aaaaaiat_s006_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaiat\s011_2012\01_tcp_ar\aaaaaiat_s011_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 743 fenêtres gardées (preictal=0, interictal=743)
#    -> 734 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaimu\s008_2014\01_tcp_ar\aaaaaimu_s008_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaiui\s001_2009\01_tcp_ar\aaaaaiui_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaajdj\s004_2014\01_tcp_ar\aaaaajdj_s004_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 309 fenêtres gardées (preictal=58, interictal=251)
#    -> 300 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaajdn\s002_2011\01_tcp_ar\aaaaajdn_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaajns\s002_2010\01_tcp_ar\aaaaajns_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaajns\s005_2010\01_tcp_ar\aaaaajns_s005_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 65 fenêtres gardées (preictal=0, interictal=65)
#    -> 56 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaajnw\s003_2010\01_tcp_ar\aaaaajnw_s003_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaajrj\s005_2012\01_tcp_ar\aaaaajrj_s005_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 344 fenêtres gardées (preictal=58, interictal=286)
#    -> 335 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaajrj\s006_2012\01_tcp_ar\aaaaajrj_s006_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaajru\s031_2014\01_tcp_ar\aaaaajru_s031_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 6 fenêtres gardées (preictal=0, interictal=6)
# ==> Traitement de edf_reduit\aaaaajsl\s002_2010\01_tcp_ar\aaaaajsl_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaakbz\s002_2010\01_tcp_ar\aaaaakbz_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 358 fenêtres gardées (preictal=30, interictal=328)
#    -> 349 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaakfo\s005_2010\01_tcp_ar\aaaaakfo_s005_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaakfo\s005_2010\01_tcp_ar\aaaaakfo_s005_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 19 fenêtres gardées (preictal=0, interictal=19)
#    -> 10 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaakfo\s008_2010\01_tcp_ar\aaaaakfo_s008_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 194 fenêtres gardées (preictal=58, interictal=136)
#    -> 185 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaakkm\s005_2011\01_tcp_ar\aaaaakkm_s005_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaakkm\s005_2011\01_tcp_ar\aaaaakkm_s005_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaakkm\s008_2011\01_tcp_ar\aaaaakkm_s008_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaakpu\s001_2010\01_tcp_ar\aaaaakpu_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 528 fenêtres gardées (preictal=58, interictal=470)
#    -> 519 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaakro\s009_2014\01_tcp_ar\aaaaakro_s009_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 1238 fenêtres gardées (preictal=0, interictal=1238)
#    -> 1229 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaksh\s003_2010\01_tcp_ar\aaaaaksh_s003_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 215 fenêtres gardées (preictal=58, interictal=157)
#    -> 206 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaalak\s002_2015\01_tcp_ar\aaaaalak_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaalak\s003_2015\01_tcp_ar\aaaaalak_s003_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaalak\s007_2015\01_tcp_ar\aaaaalak_s007_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaalnt\s001_2011\01_tcp_ar\aaaaalnt_s001_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 199 fenêtres gardées (preictal=0, interictal=199)
#    -> 190 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaalpn\s002_2014\01_tcp_ar\aaaaalpn_s002_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 61 fenêtres gardées (preictal=58, interictal=3)
#    -> 52 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaalpn\s002_2014\01_tcp_ar\aaaaalpn_s002_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 177 fenêtres gardées (preictal=58, interictal=119)
#    -> 168 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaltg\s007_2014\01_tcp_ar\aaaaaltg_s007_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 61 fenêtres gardées (preictal=47, interictal=14)
#    -> 52 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaambs\s009_2015\01_tcp_ar\aaaaambs_s009_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamhb\s013_2013\01_tcp_ar\aaaaamhb_s013_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 42 fenêtres gardées (preictal=0, interictal=42)
#    -> 33 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamhj\s002_2011\01_tcp_ar\aaaaamhj_s002_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaammu\s004_2012\01_tcp_ar\aaaaammu_s004_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamoa\s006_2012\01_tcp_ar\aaaaamoa_s006_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 162 fenêtres gardées (preictal=58, interictal=104)
#    -> 153 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamoa\s006_2012\01_tcp_ar\aaaaamoa_s006_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 231 fenêtres gardées (preictal=58, interictal=173)
#    -> 222 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamoa\s006_2012\01_tcp_ar\aaaaamoa_s006_t010.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 141 fenêtres gardées (preictal=0, interictal=141)
#    -> 132 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamoe\s007_2012\01_tcp_ar\aaaaamoe_s007_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamoq\s005_2012\01_tcp_ar\aaaaamoq_s005_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaampz\s003_2015\01_tcp_ar\aaaaampz_s003_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 130 fenêtres gardées (preictal=0, interictal=130)
#    -> 121 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamqy\s007_2013\01_tcp_ar\aaaaamqy_s007_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamqy\s007_2013\01_tcp_ar\aaaaamqy_s007_t008.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamrh\s002_2011\01_tcp_ar\aaaaamrh_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamyc\s005_2013\01_tcp_ar\aaaaamyc_s005_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaamyy\s001_2012\01_tcp_ar\aaaaamyy_s001_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 223 fenêtres gardées (preictal=58, interictal=165)
#    -> 214 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaankc\s004_2012\01_tcp_ar\aaaaankc_s004_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 363 fenêtres gardées (preictal=58, interictal=305)
#    -> 354 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanme\s001_2012\01_tcp_ar\aaaaanme_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 152 fenêtres gardées (preictal=56, interictal=96)
#    -> 143 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanme\s002_2012\01_tcp_ar\aaaaanme_s002_t009.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 163 fenêtres gardées (preictal=58, interictal=105)
#    -> 154 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanme\s003_2012\01_tcp_ar\aaaaanme_s003_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 166 fenêtres gardées (preictal=0, interictal=166)
#    -> 157 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanme\s003_2012\01_tcp_ar\aaaaanme_s003_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 257 fenêtres gardées (preictal=58, interictal=199)
#    -> 248 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanme\s006_2014\01_tcp_ar\aaaaanme_s006_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 256 fenêtres gardées (preictal=58, interictal=198)
#    -> 247 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanme\s007_2014\01_tcp_ar\aaaaanme_s007_t015.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 241 fenêtres gardées (preictal=58, interictal=183)
#    -> 232 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanme\s010_2014\01_tcp_ar\aaaaanme_s010_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 176 fenêtres gardées (preictal=58, interictal=118)
#    -> 167 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanme\s010_2014\01_tcp_ar\aaaaanme_s010_t010.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 176 fenêtres gardées (preictal=58, interictal=118)
#    -> 167 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanrb\s002_2012\01_tcp_ar\aaaaanrb_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 45 fenêtres gardées (preictal=0, interictal=45)
#    -> 36 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanrc\s002_2012\01_tcp_ar\aaaaanrc_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaanrc\s004_2012\01_tcp_ar\aaaaanrc_s004_t008.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaocy\s001_2012\01_tcp_ar\aaaaaocy_s001_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaogd\s004_2012\01_tcp_ar\aaaaaogd_s004_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaooo\s002_2013\01_tcp_ar\aaaaaooo_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 89 fenêtres gardées (preictal=58, interictal=31)
#    -> 80 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaooo\s002_2013\01_tcp_ar\aaaaaooo_s002_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 175 fenêtres gardées (preictal=58, interictal=117)
#    -> 166 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaooo\s002_2013\01_tcp_ar\aaaaaooo_s002_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 288 fenêtres gardées (preictal=58, interictal=230)
#    -> 279 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaooy\s003_2013\01_tcp_ar\aaaaaooy_s003_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaosa\s006_2014\01_tcp_ar\aaaaaosa_s006_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 67 fenêtres gardées (preictal=35, interictal=32)
#    -> 58 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaosc\s002_2013\01_tcp_ar\aaaaaosc_s002_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 55 fenêtres gardées (preictal=0, interictal=55)
#    -> 46 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaosc\s002_2013\01_tcp_ar\aaaaaosc_s002_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaouk\s007_2013\01_tcp_ar\aaaaaouk_s007_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 380 fenêtres gardées (preictal=58, interictal=322)
#    -> 371 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaouk\s008_2013\01_tcp_ar\aaaaaouk_s008_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 271 fenêtres gardées (preictal=0, interictal=271)
#    -> 262 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaoya\s012_2015\01_tcp_ar\aaaaaoya_s012_t010.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapas\s003_2013\01_tcp_ar\aaaaapas_s003_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 279 fenêtres gardées (preictal=58, interictal=221)
#    -> 270 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapas\s003_2013\01_tcp_ar\aaaaapas_s003_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapkm\s007_2013\01_tcp_ar\aaaaapkm_s007_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 192 fenêtres gardées (preictal=0, interictal=192)
#    -> 183 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapks\s002_2013\01_tcp_ar\aaaaapks_s002_t009.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 110 fenêtres gardées (preictal=58, interictal=52)
#    -> 101 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaplb\s002_2013\01_tcp_ar\aaaaaplb_s002_t020.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 321 fenêtres gardées (preictal=0, interictal=321)
#    -> 312 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapli\s002_2014\01_tcp_ar\aaaaapli_s002_t013.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 63 fenêtres gardées (preictal=58, interictal=5)
#    -> 54 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapmd\s001_2013\01_tcp_ar\aaaaapmd_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapmd\s003_2013\01_tcp_ar\aaaaapmd_s003_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 249 fenêtres gardées (preictal=0, interictal=249)
#    -> 240 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapnc\s013_2013\01_tcp_ar\aaaaapnc_s013_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 47 fenêtres gardées (preictal=0, interictal=47)
#    -> 38 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaappt\s006_2013\01_tcp_ar\aaaaappt_s006_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaapqh\s004_2013\01_tcp_ar\aaaaapqh_s004_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaprf\s001_2013\01_tcp_ar\aaaaaprf_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 111 fenêtres gardées (preictal=47, interictal=64)
#    -> 102 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqbb\s009_2014\01_tcp_ar\aaaaaqbb_s009_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 67 fenêtres gardées (preictal=48, interictal=19)
#    -> 58 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqbb\s009_2014\01_tcp_ar\aaaaaqbb_s009_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 38 fenêtres gardées (preictal=38, interictal=0)
#    -> 29 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqbb\s009_2014\01_tcp_ar\aaaaaqbb_s009_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 71 fenêtres gardées (preictal=58, interictal=13)
#    -> 62 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqbb\s010_2014\01_tcp_ar\aaaaaqbb_s010_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 42 fenêtres gardées (preictal=42, interictal=0)
#    -> 33 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqbb\s010_2014\01_tcp_ar\aaaaaqbb_s010_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaqbb\s010_2014\01_tcp_ar\aaaaaqbb_s010_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 46 fenêtres gardées (preictal=46, interictal=0)
#    -> 37 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqek\s007_2015\01_tcp_ar\aaaaaqek_s007_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 304 fenêtres gardées (preictal=0, interictal=304)
#    -> 295 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqkb\s001_2013\01_tcp_ar\aaaaaqkb_s001_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaqkb\s001_2013\01_tcp_ar\aaaaaqkb_s001_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqkb\s003_2013\01_tcp_ar\aaaaaqkb_s003_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 191 fenêtres gardées (preictal=58, interictal=133)
#    -> 182 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqkb\s005_2013\01_tcp_ar\aaaaaqkb_s005_t008.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqkh\s002_2013\01_tcp_ar\aaaaaqkh_s002_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 176 fenêtres gardées (preictal=58, interictal=118)
#    -> 167 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqkh\s003_2013\01_tcp_ar\aaaaaqkh_s003_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 164 fenêtres gardées (preictal=58, interictal=106)
#    -> 155 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqkh\s003_2013\01_tcp_ar\aaaaaqkh_s003_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 186 fenêtres gardées (preictal=58, interictal=128)
#    -> 177 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqld\s002_2014\01_tcp_ar\aaaaaqld_s002_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 261 fenêtres gardées (preictal=58, interictal=203)
#    -> 252 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqld\s002_2014\01_tcp_ar\aaaaaqld_s002_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqld\s003_2014\01_tcp_ar\aaaaaqld_s003_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 211 fenêtres gardées (preictal=58, interictal=153)
#    -> 202 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqld\s003_2014\01_tcp_ar\aaaaaqld_s003_t010.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 302 fenêtres gardées (preictal=58, interictal=244)
#    -> 293 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqld\s003_2014\01_tcp_ar\aaaaaqld_s003_t014.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqld\s003_2014\01_tcp_ar\aaaaaqld_s003_t015.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 182 fenêtres gardées (preictal=58, interictal=124)
#    -> 173 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqnr\s001_2014\01_tcp_ar\aaaaaqnr_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 651 fenêtres gardées (preictal=0, interictal=651)
#    -> 642 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqtl\s006_2014\01_tcp_ar\aaaaaqtl_s006_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqtu\s003_2014\01_tcp_ar\aaaaaqtu_s003_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 2 fenêtres gardées (preictal=0, interictal=2)
# ==> Traitement de edf_reduit\aaaaaqtw\s001_2014\01_tcp_ar\aaaaaqtw_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqtw\s002_2014\01_tcp_ar\aaaaaqtw_s002_t011.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqtx\s012_2014\01_tcp_ar\aaaaaqtx_s012_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaqtx\s012_2014\01_tcp_ar\aaaaaqtx_s012_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaqvr\s002_2014\01_tcp_ar\aaaaaqvr_s002_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqvr\s004_2014\01_tcp_ar\aaaaaqvr_s004_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaqvx\s002_2015\01_tcp_ar\aaaaaqvx_s002_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 210 fenêtres gardées (preictal=0, interictal=210)
#    -> 201 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaraf\s001_2014\01_tcp_ar\aaaaaraf_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 621 fenêtres gardées (preictal=58, interictal=563)
#    -> 612 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaardf\s001_2014\01_tcp_ar\aaaaardf_s001_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 108 fenêtres gardées (preictal=58, interictal=50)
#    -> 99 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaardf\s004_2014\01_tcp_ar\aaaaardf_s004_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 181 fenêtres gardées (preictal=58, interictal=123)
#    -> 172 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaardf\s004_2014\01_tcp_ar\aaaaardf_s004_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 183 fenêtres gardées (preictal=58, interictal=125)
#    -> 174 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaardf\s004_2014\01_tcp_ar\aaaaardf_s004_t014.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 101 fenêtres gardées (preictal=58, interictal=43)
#    -> 92 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaardf\s004_2014\01_tcp_ar\aaaaardf_s004_t016.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 177 fenêtres gardées (preictal=58, interictal=119)
#    -> 168 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaardf\s005_2014\01_tcp_ar\aaaaardf_s005_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 124 fenêtres gardées (preictal=58, interictal=66)
#    -> 115 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaardf\s005_2014\01_tcp_ar\aaaaardf_s005_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 176 fenêtres gardées (preictal=58, interictal=118)
#    -> 167 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaardf\s005_2014\01_tcp_ar\aaaaardf_s005_t010.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 176 fenêtres gardées (preictal=58, interictal=118)
#    -> 167 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarei\s007_2015\01_tcp_ar\aaaaarei_s007_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 45 fenêtres gardées (preictal=31, interictal=14)
#    -> 36 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarhk\s001_2014\01_tcp_ar\aaaaarhk_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 690 fenêtres gardées (preictal=0, interictal=690)
#    -> 681 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarjc\s007_2015\01_tcp_ar\aaaaarjc_s007_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarml\s007_2015\01_tcp_ar\aaaaarml_s007_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 432 fenêtres gardées (preictal=58, interictal=374)
#    -> 423 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarml\s007_2015\01_tcp_ar\aaaaarml_s007_t009.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarnq\s004_2014\01_tcp_ar\aaaaarnq_s004_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 188 fenêtres gardées (preictal=58, interictal=130)
#    -> 179 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarnq\s004_2014\01_tcp_ar\aaaaarnq_s004_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 59 fenêtres gardées (preictal=58, interictal=1)
#    -> 50 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarnq\s004_2014\01_tcp_ar\aaaaarnq_s004_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 61 fenêtres gardées (preictal=58, interictal=3)
#    -> 52 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaron\s001_2014\01_tcp_ar\aaaaaron_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaaroo\s001_2014\01_tcp_ar\aaaaaroo_s001_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 228 fenêtres gardées (preictal=0, interictal=228)
#    -> 219 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaroo\s003_2014\01_tcp_ar\aaaaaroo_s003_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaroo\s005_2014\01_tcp_ar\aaaaaroo_s005_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 40 fenêtres gardées (preictal=40, interictal=0)
#    -> 31 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarpu\s001_2014\01_tcp_ar\aaaaarpu_s001_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarpu\s004_2014\01_tcp_ar\aaaaarpu_s004_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarpv\s001_2014\01_tcp_ar\aaaaarpv_s001_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 184 fenêtres gardées (preictal=0, interictal=184)
#    -> 175 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarpv\s001_2014\01_tcp_ar\aaaaarpv_s001_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 179 fenêtres gardées (preictal=58, interictal=121)
#    -> 170 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarpv\s002_2014\01_tcp_ar\aaaaarpv_s002_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarpv\s002_2014\01_tcp_ar\aaaaarpv_s002_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 35 fenêtres gardées (preictal=35, interictal=0)
#    -> 26 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s001_2014\01_tcp_ar\aaaaarsm_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 124 fenêtres gardées (preictal=0, interictal=124)
#    -> 115 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s002_2014\01_tcp_ar\aaaaarsm_s002_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 61 fenêtres gardées (preictal=45, interictal=16)
#    -> 52 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s002_2014\01_tcp_ar\aaaaarsm_s002_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 68 fenêtres gardées (preictal=50, interictal=18)
#    -> 59 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s002_2014\01_tcp_ar\aaaaarsm_s002_t009.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaarsm\s003_2014\01_tcp_ar\aaaaarsm_s003_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s004_2014\01_tcp_ar\aaaaarsm_s004_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 144 fenêtres gardées (preictal=58, interictal=86)
#    -> 135 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s007_2014\01_tcp_ar\aaaaarsm_s007_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 61 fenêtres gardées (preictal=46, interictal=15)
#    -> 52 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s007_2014\01_tcp_ar\aaaaarsm_s007_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=44, interictal=14)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s007_2014\01_tcp_ar\aaaaarsm_s007_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 61 fenêtres gardées (preictal=46, interictal=15)
#    -> 52 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarsm\s007_2014\01_tcp_ar\aaaaarsm_s007_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 66 fenêtres gardées (preictal=46, interictal=20)
#    -> 57 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarso\s005_2014\01_tcp_ar\aaaaarso_s005_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 104 fenêtres gardées (preictal=0, interictal=104)
#    -> 95 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaarso\s005_2014\01_tcp_ar\aaaaarso_s005_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 197 fenêtres gardées (preictal=0, interictal=197)
#    -> 188 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasfw\s005_2015\01_tcp_ar\aaaaasfw_s005_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 195 fenêtres gardées (preictal=58, interictal=137)
#    -> 186 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasfw\s005_2015\01_tcp_ar\aaaaasfw_s005_t011.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 177 fenêtres gardées (preictal=58, interictal=119)
#    -> 168 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasip\s001_2015\01_tcp_ar\aaaaasip_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 370 fenêtres gardées (preictal=58, interictal=312)
#    -> 361 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasip\s002_2015\01_tcp_ar\aaaaasip_s002_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 58 fenêtres gardées (preictal=58, interictal=0)
#    -> 49 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasip\s002_2015\01_tcp_ar\aaaaasip_s002_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 139 fenêtres gardées (preictal=58, interictal=81)
#    -> 130 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasjh\s001_2015\01_tcp_ar\aaaaasjh_s001_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 213 fenêtres gardées (preictal=58, interictal=155)
#    -> 204 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasoc\s004_2015\01_tcp_ar\aaaaasoc_s004_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 118 fenêtres gardées (preictal=0, interictal=118)
#    -> 109 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasut\s001_2015\01_tcp_ar\aaaaasut_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 406 fenêtres gardées (preictal=0, interictal=406)
#    -> 397 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaasut\s003_2015\01_tcp_ar\aaaaasut_s003_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 259 fenêtres gardées (preictal=58, interictal=201)
#    -> 250 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaaswc\s002_2015\01_tcp_ar\aaaaaswc_s002_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 48 fenêtres gardées (preictal=48, interictal=0)
#    -> 39 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatao\s002_2015\01_tcp_ar\aaaaatao_s002_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 207 fenêtres gardées (preictal=58, interictal=149)
#    -> 198 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatao\s002_2015\01_tcp_ar\aaaaatao_s002_t008.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 188 fenêtres gardées (preictal=58, interictal=130)
#    -> 179 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatao\s003_2015\01_tcp_ar\aaaaatao_s003_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaatba\s002_2015\01_tcp_ar\aaaaatba_s002_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 223 fenêtres gardées (preictal=58, interictal=165)
#    -> 214 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatba\s002_2015\01_tcp_ar\aaaaatba_s002_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 106 fenêtres gardées (preictal=58, interictal=48)
#    -> 97 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatba\s003_2015\01_tcp_ar\aaaaatba_s003_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 181 fenêtres gardées (preictal=58, interictal=123)
#    -> 172 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatba\s004_2015\01_tcp_ar\aaaaatba_s004_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 299 fenêtres gardées (preictal=0, interictal=299)
#    -> 290 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatds\s002_2015\01_tcp_ar\aaaaatds_s002_t002.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaatds\s002_2015\01_tcp_ar\aaaaatds_s002_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaatds\s002_2015\01_tcp_ar\aaaaatds_s002_t009.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaatdt\s001_2015\01_tcp_ar\aaaaatdt_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaatdt\s003_2015\01_tcp_ar\aaaaatdt_s003_t007.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 132 fenêtres gardées (preictal=58, interictal=74)
#    -> 123 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaates\s009_2015\01_tcp_ar\aaaaates_s009_t003.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 178 fenêtres gardées (preictal=58, interictal=120)
#    -> 169 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatez\s001_2015\01_tcp_ar\aaaaatez_s001_t000.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 59 fenêtres gardées (preictal=41, interictal=18)
#    -> 50 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatez\s006_2015\01_tcp_ar\aaaaatez_s006_t004.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaatez\s007_2015\01_tcp_ar\aaaaatez_s007_t001.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 186 fenêtres gardées (preictal=0, interictal=186)
#    -> 177 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatlp\s004_2015\01_tcp_ar\aaaaatlp_s004_t006.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 248 fenêtres gardées (preictal=30, interictal=218)
#    -> 239 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatvk\s002_2015\01_tcp_ar\aaaaatvk_s002_t021.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 149 fenêtres gardées (preictal=0, interictal=149)
#    -> 140 séquences de 10 fenêtres créées.
# ==> Traitement de edf_reduit\aaaaatvr\s001_2015\01_tcp_ar\aaaaatvr_s001_t013.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 0 fenêtres gardées (preictal=0, interictal=0)
# ==> Traitement de edf_reduit\aaaaatvr\s004_2015\01_tcp_ar\aaaaatvr_s004_t005.edf
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
#    -> 2 fenêtres gardées (preictal=0, interictal=2)
#
# Index fenêtres (brut) sauvegardé dans prepared\all\windows_index_all.csv (32103 lignes)
# Index séquences (brut) sauvegardé dans prepared\all\sequences_index_all.csv (30563 lignes)
#
# [STATS] Fenêtres totales: 32103 (preictal=5718, interictal=26385)
# [OK] Index fenêtres équilibré: 11436 lignes (≈ 5718 + 5718).
# Index fenêtres équilibré sauvegardé dans prepared\all\train_windows_index_balanced.csv
#
# [STATS] Séquences totales: 30563 (preictal=4773, interictal=25790)
# [OK] Index séquences équilibré: 9546 lignes (≈ 4773 + 4773).
# Index séquences équilibré sauvegardé dans prepared\all\train_sequences_index_balanced.csv
